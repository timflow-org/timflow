# %% [markdown]
# # Test bessel performance

# %%
from timflow.bessel.besselnumba import (
    besselld_gauss_ho_d1d2,
    besselld_gauss_ho_qxqy_d1d2,
    besselld_int_ho,
    besselld_int_ho_qxqy,
    bessells_gauss_ho_d1d2,
    bessells_gauss_ho_qxqy_d1d2,
    bessells_int_ho,
    bessells_int_ho_qxqy,
)

# %%
# test data
x = 2
y = 3
d = 0.0001
z1 = -1 - 2j
z2 = 2 + 1j
d1 = -0.5
d2 = 0.2
lab1 = 8.0
order1 = 7
lab2 = 8 + 3j
order2 = 3

# %%
lab = lab1
order = order1

# %%
#
pot = bessells_int_ho(x, y, z1, z2, lab, order, d1, d2)
potgauss = bessells_gauss_ho_d1d2(x, y, z1, z2, lab, order, d1, d2)

#
qxqy = bessells_int_ho_qxqy(x, y, z1, z2, lab, order, d1, d2)
qxqygauss = bessells_gauss_ho_qxqy_d1d2(x, y, z1, z2, lab, order, d1, d2)

#
pot = besselld_int_ho(x, y, z1, z2, lab, order, d1, d2)
potgauss = besselld_gauss_ho_d1d2(x, y, z1, z2, lab, order, d1, d2)

#
qxqy = besselld_int_ho_qxqy(x, y, z1, z2, lab, order, d1, d2)
qxqygauss = besselld_gauss_ho_qxqy_d1d2(x, y, z1, z2, lab, order, d1, d2)

# %% [markdown]
# ### Discharge potential line-sink

# %%
lab = lab1
order = order1

# %%
# %timeit pot = bessells_int_ho(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 11.8 μs ± 176 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit potgauss = bessells_gauss_ho_d1d2(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 1.01 μs ± 12.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
lab = lab2
order = order2

# %%
# %timeit pot = bessells_int_ho(x, y, z1, z2, lab, order, d1, d2)
# Out:
# The slowest run took 4.94 times longer than the fastest. This could mean that an intermediate result is being cached.
# 9.28 μs ± 7.45 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit potgauss = bessells_gauss_ho_d1d2(x, y, z1, z2, lab, order, d1, d2)
# Out:
# The slowest run took 31.01 times longer than the fastest. This could mean that an intermediate result is being cached.
# 6.06 μs ± 11.5 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Discharge vector line-sink

# %%
lab = lab1
order = order1

# %%
# %timeit qxqy = bessells_int_ho_qxqy(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 14.3 μs ± 267 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit qxqygauss = bessells_gauss_ho_qxqy_d1d2(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 2.11 μs ± 108 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Discharge potential line-doublet

# %%
lab = lab1
order = order1

# %%
# %timeit pot = besselld_int_ho(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 12.1 μs ± 170 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit besselld_gauss_ho_d1d2(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 879 ns ± 11.4 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Discharge vector line-doublet

# %%
lab = lab1
order = order1

# %%
# %timeit qxqy = besselld_int_ho_qxqy(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 26.3 μs ± 1.16 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit qxqygauss = besselld_gauss_ho_qxqy_d1d2(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 2.05 μs ± 38.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
